# %% [markdown]
# # Laptop Price Predictor Using Regression

# %% [markdown]
# ## Step 1. Importing Essential Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# This line of code reads a CSV file named "laptop_data.csv" using pandas 
# and loads its contents into a pandas dataframe called "df". 
df = pd.read_csv("laptop_data.csv")

# %% [markdown]
# ## Step 2. Analysing and Visualizing the Data (Data Preprocessing)

# %%
# Now let's see the first 5 rows of the 'df' dataframe
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
# Let's understand out data better by seeing the summary of various columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
# Let's check if there are any duplicate rows in the dataframe
df.duplicated().sum()
# Out:
# 0

# %%
# Let's check for any missing or null values in ur dataframe
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# Here we don't need the column 'Unnamed'. Let's delete it.
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080

# %%
# Let's remove the 'GB' part in Ram and 'kg' part in Weight as it will interfere with our training of model
df['Ram'] = df['Ram'].str.replace('GB', '')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
# Let's rename the 'Ram' column to 'RAM'
df = df.rename(columns={'Ram': 'RAM'})

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu RAM               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
# Let's rename the 'ScreenResolution' column to 'Screen Resolution'
df = df.rename(columns={'ScreenResolution': 'Screen Resolution'})

# %%
# Let's rename the 'TypeName' column to 'Type Name'
df = df.rename(columns={'TypeName': 'Type Name'})

# %%
df.head()
# Out:
#   Company  Type Name  Inches                   Screen Resolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu RAM               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080

# %%
# Let's convert the datatypes of two columns: 'RAM' and 'Weight'
# RAM datatype will now be int32
# Weight datatype will now be float32

df['RAM'] = df['RAM'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.head()
# Out:
#   Company  Type Name  Inches                   Screen Resolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1303 non-null   object
#  1   Type Name          1303 non-null   object
#  2   Inches             1303 non-null   float64
#  3   Screen Resolution  1303 non-null   object
#  4   Cpu                1303 non-null   object
#  5   RAM                1303 non-null   int32
#  6   Memory             1303 non-null   object
#  7   Gpu                1303 non-null   object
#  8   OpSys              1303 non-null   object
#  9   Weight             1303 non-null   float32
#  10  Price              1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
# Importing seaborn - it is used to create atractive and useful statistical graphics
import seaborn as sns

# %%
# Let's create a histogram of the distribution of the price variable
sns.histplot(df['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
# Let's see the frequency of unique laptop brands in our database using a barplot
df['Company'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Let's see the correlation of different laptop brands and price
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Let's see the correlation of different laptop types and price
sns.barplot(x=df['Type Name'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Let's see the correlation of different laptop screen size(in inches) and price
sns.barplot(x=df['Inches'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Count of unique values in 'Screen Resolution' column
df['Screen Resolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ 2560x1440                       3
# Quad HD+ 3200x1800                                 3
# 1920x1080                                          3
# Touchscreen 2400x1600                              3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Full HD 1920x1200                        1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Full HD 1920x1080                    1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / 4K Ultra HD 3840x2160                1
# IPS Panel Touchscreen 2400x1600                    1
# Name: Screen Resolution, dtype: int64

# %%
# Let's create a new column called 'Touchscreen' indicating whether a laptop has touchscreen display or not
df['Touchscreen'] = df['Screen Resolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company  Type Name  Inches                   Screen Resolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0

# %%
# Barplot of 'Touchscreen' column and their frequency
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#   Company  Type Name  Inches                   Screen Resolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0

# %%
# Let's create a new column called 'IPS' indicating whether a laptop has IPS Panel or not
df['IPS'] = df['Screen Resolution'].apply(lambda x:1 if 'IPS Panel' in x else 0)

# %%
df.head()
# Out:
#   Company  Type Name  Inches                   Screen Resolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1

# %%
df['IPS'].value_counts()
# Out:
# 0    938
# 1    365
# Name: IPS, dtype: int64

# %%
# Let's create a variable which splits the 'Screen Resolution' column with 'x' as delimiter
new = df['Screen Resolution'].str.split('x',n=1,expand=True)

# %%
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
# Let's create two new columns X_res and Y_res to store the x and y resolutions of the screen
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.head()
# Out:
#   Company  Type Name  Inches                   Screen Resolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#                            X_res Y_res
# 0  IPS Panel Retina Display 2560  1600
# 1                           1440   900
# 2                   Full HD 1920  1080
# 3  IPS Panel Retina Display 2880  1800
# 4  IPS Panel Retina Display 2560  1600

# %%
# Since X_res has unnecessary data let's remove that and only keep the X_res value
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x: x[0])

# %%
df.head()
# Out:
#   Company  Type Name  Inches                   Screen Resolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#   X_res Y_res
# 0  2560  1600
# 1  1440   900
# 2  1920  1080
# 3  2880  1800
# 4  2560  1600

# %%
df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)')
# Out:
# 0       [2560]
# 1       [1440]
# 2       [1920]
# 3       [2880]
# 4       [2560]
#          ...
# 1298    [1920]
# 1299    [3200]
# 1300    [1366]
# 1301    [1366]
# 1302    [1366]
# Name: X_res, Length: 1303, dtype: object

# %%
# Convert X_res and Y_res datatype from sting to int
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1303 non-null   object
#  1   Type Name          1303 non-null   object
#  2   Inches             1303 non-null   float64
#  3   Screen Resolution  1303 non-null   object
#  4   Cpu                1303 non-null   object
#  5   RAM                1303 non-null   int32
#  6   Memory             1303 non-null   object
#  7   Gpu                1303 non-null   object
#  8   OpSys              1303 non-null   object
#  9   Weight             1303 non-null   float32
#  10  Price              1303 non-null   float64
#  11  Touchscreen        1303 non-null   int64
#  12  IPS                1303 non-null   int64
#  13  X_res              1303 non-null   int32
#  14  Y_res              1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# memory usage: 132.5+ KB

# %%
# Let's see the correlation of price with different columns in the dataframe
df.corr()['Price']
# Out:
# Inches         0.068197
# RAM            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
# Let's create a new column called PPI 
df['PPI'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.head()
# Out:
#   Company  Type Name  Inches                   Screen Resolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  RAM               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    X_res  Y_res         PPI
# 0   2560   1600  226.983005
# 1   1440    900  127.677940
# 2   1920   1080  141.211998
# 3   2880   1800  220.534624
# 4   2560   1600  226.983005

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# RAM            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# PPI            0.473487
# Name: Price, dtype: float64

# %%
# Since we no longer need Screen Resolution, Inches, X_res and Y_res; let's delete those rows
df.drop(columns=['Screen Resolution','Inches', 'X_res', 'Y_res'], inplace=True)

# %%
df.head()
# Out:
#   Company  Type Name                         Cpu  RAM               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI
# 0  226.983005
# 1  127.677940
# 2  141.211998
# 3  220.534624
# 4  226.983005

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# Let's split the data in Cpu column into words
df['Cpu'].apply(lambda x: x.split())
# Out:
# 0                         [Intel, Core, i5, 2.3GHz]
# 1                         [Intel, Core, i5, 1.8GHz]
# 2                  [Intel, Core, i5, 7200U, 2.5GHz]
# 3                         [Intel, Core, i7, 2.7GHz]
# 4                         [Intel, Core, i5, 3.1GHz]
#                            ...
# 1298               [Intel, Core, i7, 6500U, 2.5GHz]
# 1299               [Intel, Core, i7, 6500U, 2.5GHz]
# 1300    [Intel, Celeron, Dual, Core, N3050, 1.6GHz]
# 1301               [Intel, Core, i7, 6500U, 2.5GHz]
# 1302    [Intel, Celeron, Dual, Core, N3050, 1.6GHz]
# Name: Cpu, Length: 1303, dtype: object

# %%
# Let's create a new column CPU Name whoch stores only the first three words of the Cpu column
df['CPU Name'] = df['Cpu'].apply(lambda x: " ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company  Type Name                         Cpu  RAM               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU Name
# 0  226.983005  Intel Core i5
# 1  127.677940  Intel Core i5
# 2  141.211998  Intel Core i5
# 3  220.534624  Intel Core i7
# 4  226.983005  Intel Core i5

# %%
# This function takes a Cpu name as input ans returns the CPU Brand of it

def fetch_processor(text):
    if text == 'Intel Core i3' or text == 'Intel Core i5' or text == 'Intel Core i7':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
# Let's create CPU Brand column using the above function
df['CPU Brand'] = df['CPU Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company  Type Name                         Cpu  RAM               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           PPI       CPU Name      CPU Brand
# 0  226.983005  Intel Core i5  Intel Core i5
# 1  127.677940  Intel Core i5  Intel Core i5
# 2  141.211998  Intel Core i5  Intel Core i5
# 3  220.534624  Intel Core i7  Intel Core i7
# 4  226.983005  Intel Core i5  Intel Core i5

# %%
df['CPU Brand'].value_counts()
# Out:
# Intel Core i7            527
# Intel Core i5            423
# Other Intel Processor    154
# Intel Core i3            136
# AMD Processor             63
# Name: CPU Brand, dtype: int64

# %%
df['CPU Brand'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['CPU Brand'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(['Cpu', 'CPU Name'], inplace=True, axis=1)

# %%
df.head()
# Out:
#   Company  Type Name  RAM               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         PPI      CPU Brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['RAM'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['RAM'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   Company  Type Name  RAM               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         PPI      CPU Brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 1TB HDD +  1TB HDD                 1
# 32GB HDD                           1
# 64GB SSD                           1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: Memory, dtype: int64

# %%
# In the following code we are doing the following:
# We are creating 4 different columns called HDD, SSD, Hybrid and Flash_Storage
# Based on the values in Memory column, we are filling the corresponding values in the four columns
# For example: Memory: 128GB SSD + 1TB HDD --> HDD = 1024, SSD = 128, Hybrid = 0, Flahs_Storage=0

df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# C:\Users\NAVEEN SURATHU\AppData\Local\Temp\ipykernel_17960\2413234045.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['first'] = df['first'].str.replace(r'\D', '')
# C:\Users\NAVEEN SURATHU\AppData\Local\Temp\ipykernel_17960\2413234045.py:30: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['second'] = df['second'].str.replace(r'\D', '')

# %%
df.head()
# Out:
#   Company  Type Name  RAM             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         PPI      CPU Brand  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage
# 0    0  128       0              0
# 1    0    0       0            128
# 2    0  256       0              0
# 3    0  512       0              0
# 4    0  256       0              0

# %%
# Since we no longer need the Memory column we will simply drop(or delete) it
df.drop(columns=['Memory'], inplace=True)

# %%
df.head()
# Out:
#   Company  Type Name  RAM                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI      CPU Brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256       0
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512       0
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
df.corr()['Price']
# Out:
# RAM              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# IPS              0.252208
# PPI              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
# Since Flash_Storage and Hybrid have very weak correlation with Price(our target vairable), it is safe
#to drop these columns

df.drop(columns=['Flash_Storage', 'Hybrid'], inplace=True)

# %%
df.head()
# Out:
#   Company  Type Name  RAM                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI      CPU Brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df['Gpu'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Let's create a new column GPU Brand which takes the first word of column Gpu and stores it
df['GPU Brand'] = df['Gpu'].apply(lambda x : x.split()[0])

# %%
df.head()
# Out:
#   Company  Type Name  RAM                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         PPI      CPU Brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   GPU Brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['GPU Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: GPU Brand, dtype: int64

# %%
sns.barplot(x=df['GPU Brand'], y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df = df[df['GPU Brand'] != 'ARM']

# %%
df['GPU Brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: GPU Brand, dtype: int64

# %%
# Let's drop Gpu column
df.drop(columns=['Gpu'], inplace=True)

# %%
df.head()
# Out:
#   Company  Type Name  RAM  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      CPU Brand  HDD  SSD GPU Brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
# The below function takes a oeprating system as parameter and returns whether the OS is Windows,
# Mac or Other

def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
# Let's create a new column OS using the above function
df['OS'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company  Type Name  RAM  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           PPI      CPU Brand  HDD  SSD GPU Brand                  OS
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df['OS'].value_counts()
# Out:
# Windows               1125
# Others/No OS/Linux     156
# Mac                     21
# Name: OS, dtype: int64

# %%
# Let's drop OpSys column
df.drop(columns=['OpSys'], inplace=True)

# %%
df.head()
# Out:
#   Company  Type Name  RAM  Weight        Price  Touchscreen  IPS         PPI  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        CPU Brand  HDD  SSD GPU Brand                  OS
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
# Let's visualize the frequencies of different weights with a distplot
sns.distplot(df['Weight'])
# Out:
# c:\Users\NAVEEN SURATHU\OneDrive\Documents\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
df.corr()
# Out:
#                   RAM    Weight     Price  Touchscreen       IPS       PPI  \
# RAM          1.000000  0.383362  0.742905     0.118875  0.207949  0.305688
# Weight       0.383362  1.000000  0.209867    -0.293004  0.018643 -0.321883
# Price        0.742905  0.209867  1.000000     0.192917  0.253320  0.475368
# Touchscreen  0.118875 -0.293004  0.192917     1.000000  0.148026  0.458571
# IPS          0.207949  0.018643  0.253320     0.148026  1.000000  0.299142
# PPI          0.305688 -0.321883  0.475368     0.458571  0.299142  1.000000
# HDD          0.095808  0.514147 -0.096891    -0.208766 -0.093588 -0.294698
# SSD          0.603379 -0.063818  0.670660     0.257577  0.225311  0.509437
#
#                   HDD       SSD
# RAM          0.095808  0.603379
# Weight       0.514147 -0.063818
# Price       -0.096891  0.670660
# Touchscreen -0.208766  0.257577
# IPS         -0.093588  0.225311
# PPI         -0.294698  0.509437
# HDD          1.000000 -0.400750
# SSD         -0.400750  1.000000

# %%
# Let's visualize correlation of different columns with each other using a heatmap
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# While using our model we will use logarithm of our price since it is less skewed and 
# more convenient to work with
sns.distplot(np.log(df['Price']))
# Out:
# c:\Users\NAVEEN SURATHU\OneDrive\Documents\New folder\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# ## Step 3. Training the Model

# %%
# Let's now seperate the independent variables(features) and the dependent variable(target)
# X --> features
# y --> target

X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1302 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1302 non-null   object
#  1   Type Name    1302 non-null   object
#  2   RAM          1302 non-null   int32
#  3   Weight       1302 non-null   float32
#  4   Touchscreen  1302 non-null   int64
#  5   IPS          1302 non-null   int64
#  6   PPI          1302 non-null   float64
#  7   CPU Brand    1302 non-null   object
#  8   HDD          1302 non-null   int64
#  9   SSD          1302 non-null   int64
#  10  GPU Brand    1302 non-null   object
#  11  OS           1302 non-null   object
# dtypes: float32(1), float64(1), int32(1), int64(4), object(5)
# memory usage: 122.1+ KB

# %%
X
# Out:
#      Company           Type Name  RAM  Weight  Touchscreen  IPS         PPI  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
#                   CPU Brand   HDD  SSD GPU Brand                  OS
# 0             Intel Core i5     0  128     Intel                 Mac
# 1             Intel Core i5     0    0     Intel                 Mac
# 2             Intel Core i5     0  256     Intel  Others/No OS/Linux
# 3             Intel Core i7     0  512       AMD                 Mac
# 4             Intel Core i5     0  256     Intel                 Mac
# ...                     ...   ...  ...       ...                 ...
# 1298          Intel Core i7     0  128     Intel             Windows
# 1299          Intel Core i7     0  512     Intel             Windows
# 1300  Other Intel Processor     0    0     Intel             Windows
# 1301          Intel Core i7  1000    0       AMD             Windows
# 1302  Other Intel Processor   500    0     Intel             Windows
#
# [1302 rows x 12 columns]

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
# Let's split the data into X_train, X_test, y_train and y_test
# We will use X_train and y_train to train the model and X_test and y_test to test the model
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2)

# %%
X_train
# Out:
#       Company           Type Name  RAM  Weight  Touchscreen  IPS         PPI  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
#                   CPU Brand   HDD  SSD GPU Brand                  OS
# 183           Intel Core i5     0  128     Intel             Windows
# 1141          Intel Core i7  1000  128    Nvidia             Windows
# 1049  Other Intel Processor     0    0     Intel  Others/No OS/Linux
# 1020          Intel Core i3  1000    0     Intel             Windows
# 878           Intel Core i5  1000  128    Nvidia             Windows
# ...                     ...   ...  ...       ...                 ...
# 466           Intel Core i3   500    0    Nvidia             Windows
# 299           Intel Core i7     0  512    Nvidia             Windows
# 493           AMD Processor  1000    0       AMD             Windows
# 527           Intel Core i3  2000    0    Nvidia  Others/No OS/Linux
# 1193  Other Intel Processor     0    0     Intel                 Mac
#
# [1106 rows x 12 columns]

# %% [markdown]
# ## Step 4. Testing Different Models

# %%
# Importing essential libraries
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
# Importing essential libraries to use different regression models
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# ### Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred) )
# Out:
# R2 score 0.8073277448418621
# MAE 0.21017827976428963

# %% [markdown]
# ### Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8127331031311811
# MAE 0.20926802242582948

# %% [markdown]
# ### Lasso Regression
# Lasso regression is another form of regularized linear regression that, similar to ridge regression, adds a penalty term to the sum of the squared errors. However, the penalty term used in lasso regression is based on the absolute value of the coefficients, rather than their squared values. This results in a sparser model, where some of the coefficients are forced to be exactly zero. Lasso regression is useful for feature selection, as it can automatically identify and exclude irrelevant or redundant features. Additionally, lasso regression can be used to perform variable selection and reduce the complexity of the model, which can improve its interpretability and generalization performance.

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8071853945317105
# MAE 0.21114361613472568

# %% [markdown]
# ### K-Nearest Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8021984604448553
# MAE 0.19319716721521116

# %% [markdown]
# Decision Tree Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8443532781209442
# MAE 0.18028110031451508

# %% [markdown]
# ###  Support Vector Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.808318090228966
# MAE 0.20239059427193437

# %% [markdown]
# ###  Extra Trees Regression

# %%
bootstrap = True

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=None if bootstrap else 0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8753793123440623
# MAE 0.15979519126758127

# %% [markdown]
# ### AdaBoost Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7868667965313076
# MAE 0.23411972598515415

# %% [markdown]
# ### XGB Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8771404806375557
# MAE 0.16262936288951352

# %% [markdown]
# ### Gradient Boost Regresion

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8827744657097254
# MAE 0.15906054236360648

# %% [markdown]
# ### ElasticNet

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score, mean_absolute_error

# Step 1: Define the data preprocessing step using ColumnTransformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

# Step 2: Define the Elastic Net regression model
step2 = ElasticNet(alpha=0.01, l1_ratio=0.01,max_iter=50)  # You can adjust alpha and l1_ratio as needed

# Step 3: Create the pipeline with the preprocessing and regression steps
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Step 4: Fit the pipeline to the training data
pipe.fit(X_train, y_train)

# Step 5: Make predictions on the test data
y_pred = pipe.predict(X_test)

# Step 6: Evaluate the model's performance
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8127612393898219
# MAE: 0.20931205415401571

# %% [markdown]
# ### CatBoost Regression

# %%
from catboost import CatBoostRegressor

# Define your X_train and y_train here

# Define the ColumnTransformer for one-hot encoding
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

# Define the CatBoost Regressor
step2 = CatBoostRegressor(iterations=100, learning_rate=0.5)  # You can adjust the hyperparameters as needed

# Create the pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Fit the pipeline to the training data
pipe.fit(X_train, y_train)

# Make predictions on the test data
y_pred = pipe.predict(X_test)

# Evaluate the model
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# 0:	learn: 0.4508479	total: 1.29ms	remaining: 128ms
# 1:	learn: 0.3473907	total: 2.56ms	remaining: 126ms
# 2:	learn: 0.2911166	total: 3.68ms	remaining: 119ms
# 3:	learn: 0.2679632	total: 4.82ms	remaining: 116ms
# 4:	learn: 0.2507735	total: 5.96ms	remaining: 113ms
# 5:	learn: 0.2388794	total: 7.23ms	remaining: 113ms
# 6:	learn: 0.2354316	total: 8.28ms	remaining: 110ms
# 7:	learn: 0.2319197	total: 9.76ms	remaining: 112ms
# 8:	learn: 0.2227596	total: 11.1ms	remaining: 112ms
# 9:	learn: 0.2199654	total: 12.4ms	remaining: 111ms
# 10:	learn: 0.2169785	total: 13.8ms	remaining: 112ms
# 11:	learn: 0.2130735	total: 15.2ms	remaining: 111ms
# 12:	learn: 0.2076862	total: 16.4ms	remaining: 110ms
# 13:	learn: 0.2059676	total: 17.5ms	remaining: 107ms
# 14:	learn: 0.2033635	total: 18.5ms	remaining: 105ms
# 15:	learn: 0.1992673	total: 19.9ms	remaining: 105ms
# 16:	learn: 0.1951610	total: 21.4ms	remaining: 105ms
# 17:	learn: 0.1937978	total: 22.7ms	remaining: 103ms
# 18:	learn: 0.1926456	total: 24.3ms	remaining: 104ms
# 19:	learn: 0.1894719	total: 26.4ms	remaining: 106ms
# 20:	learn: 0.1871801	total: 27.6ms	remaining: 104ms
# 21:	learn: 0.1847707	total: 28.7ms	remaining: 102ms
# 22:	learn: 0.1838888	total: 29.8ms	remaining: 99.9ms
# 23:	learn: 0.1835127	total: 30.4ms	remaining: 96.3ms
# 24:	learn: 0.1798188	total: 31.6ms	remaining: 94.7ms
# 25:	learn: 0.1792073	total: 32.7ms	remaining: 93.1ms
# 26:	learn: 0.1769271	total: 33.8ms	remaining: 91.4ms
# 27:	learn: 0.1767594	total: 34.9ms	remaining: 89.7ms
# 28:	learn: 0.1736207	total: 35.9ms	remaining: 88ms
# 29:	learn: 0.1709924	total: 38.3ms	remaining: 89.4ms
# 30:	learn: 0.1705082	total: 39.9ms	remaining: 88.9ms
# 31:	learn: 0.1683130	total: 41.4ms	remaining: 88ms
# 32:	learn: 0.1682043	total: 42.6ms	remaining: 86.4ms
# 33:	learn: 0.1665665	total: 43.7ms	remaining: 84.7ms
# 34:	learn: 0.1643309	total: 44.7ms	remaining: 83.1ms
# 35:	learn: 0.1615087	total: 45.9ms	remaining: 81.5ms
# 36:	learn: 0.1603921	total: 47.1ms	remaining: 80.1ms
# 37:	learn: 0.1597008	total: 48.1ms	remaining: 78.5ms
# 38:	learn: 0.1582592	total: 49.2ms	remaining: 77ms
# 39:	learn: 0.1580594	total: 50.2ms	remaining: 75.3ms
# 40:	learn: 0.1575264	total: 51.4ms	remaining: 73.9ms
# 41:	learn: 0.1571961	total: 52.7ms	remaining: 72.8ms
# 42:	learn: 0.1571192	total: 54.1ms	remaining: 71.7ms
# 43:	learn: 0.1560792	total: 56.5ms	remaining: 71.9ms
# 44:	learn: 0.1554006	total: 57.6ms	remaining: 70.4ms
# 45:	learn: 0.1522598	total: 58.9ms	remaining: 69.1ms
# 46:	learn: 0.1522131	total: 60ms	remaining: 67.7ms
# 47:	learn: 0.1500163	total: 61.1ms	remaining: 66.2ms
# 48:	learn: 0.1483297	total: 62.4ms	remaining: 65ms
# 49:	learn: 0.1478196	total: 63.7ms	remaining: 63.7ms
# 50:	learn: 0.1464622	total: 64.9ms	remaining: 62.4ms
# 51:	learn: 0.1450922	total: 66ms	remaining: 60.9ms
# 52:	learn: 0.1447122	total: 67.3ms	remaining: 59.7ms
# 53:	learn: 0.1432780	total: 68.9ms	remaining: 58.7ms
# 54:	learn: 0.1425667	total: 70.3ms	remaining: 57.5ms
# 55:	learn: 0.1418214	total: 71.5ms	remaining: 56.2ms
# 56:	learn: 0.1401839	total: 72.6ms	remaining: 54.8ms
# 57:	learn: 0.1381460	total: 73.9ms	remaining: 53.5ms
# 58:	learn: 0.1380432	total: 75.1ms	remaining: 52.2ms
# 59:	learn: 0.1356943	total: 76.3ms	remaining: 50.9ms
# 60:	learn: 0.1346016	total: 77.4ms	remaining: 49.5ms
# 61:	learn: 0.1339249	total: 78.5ms	remaining: 48.1ms
# 62:	learn: 0.1328629	total: 79.6ms	remaining: 46.8ms
# 63:	learn: 0.1326923	total: 80.7ms	remaining: 45.4ms
# 64:	learn: 0.1312262	total: 82.1ms	remaining: 44.2ms
# 65:	learn: 0.1308548	total: 83.6ms	remaining: 43.1ms
# 66:	learn: 0.1292090	total: 84.9ms	remaining: 41.8ms
# 67:	learn: 0.1280252	total: 86.1ms	remaining: 40.5ms
# 68:	learn: 0.1279862	total: 86.7ms	remaining: 38.9ms
# 69:	learn: 0.1269350	total: 87.8ms	remaining: 37.6ms
# 70:	learn: 0.1269061	total: 88.8ms	remaining: 36.3ms
# 71:	learn: 0.1261072	total: 90.2ms	remaining: 35.1ms
# 72:	learn: 0.1257329	total: 91.7ms	remaining: 33.9ms
# 73:	learn: 0.1240656	total: 93ms	remaining: 32.7ms
# 74:	learn: 0.1233381	total: 94.1ms	remaining: 31.4ms
# 75:	learn: 0.1233027	total: 95.1ms	remaining: 30ms
# 76:	learn: 0.1225751	total: 96.4ms	remaining: 28.8ms
# 77:	learn: 0.1219873	total: 98.1ms	remaining: 27.7ms
# 78:	learn: 0.1215636	total: 99.5ms	remaining: 26.5ms
# 79:	learn: 0.1210519	total: 101ms	remaining: 25.2ms
# 80:	learn: 0.1202409	total: 102ms	remaining: 23.9ms
# 81:	learn: 0.1197878	total: 103ms	remaining: 22.6ms
# 82:	learn: 0.1191058	total: 104ms	remaining: 21.3ms
# 83:	learn: 0.1188777	total: 105ms	remaining: 20.1ms
# 84:	learn: 0.1184409	total: 106ms	remaining: 18.8ms
# 85:	learn: 0.1182051	total: 108ms	remaining: 17.5ms
# 86:	learn: 0.1169780	total: 109ms	remaining: 16.3ms
# 87:	learn: 0.1167715	total: 111ms	remaining: 15.1ms
# 88:	learn: 0.1162587	total: 112ms	remaining: 13.9ms
# 89:	learn: 0.1159274	total: 114ms	remaining: 12.6ms
# 90:	learn: 0.1156648	total: 115ms	remaining: 11.4ms
# 91:	learn: 0.1153724	total: 116ms	remaining: 10.1ms
# 92:	learn: 0.1144336	total: 117ms	remaining: 8.84ms
# 93:	learn: 0.1142054	total: 118ms	remaining: 7.56ms
# 94:	learn: 0.1141911	total: 119ms	remaining: 6.29ms
# 95:	learn: 0.1136804	total: 121ms	remaining: 5.03ms
# 96:	learn: 0.1126932	total: 122ms	remaining: 3.77ms
# 97:	learn: 0.1126814	total: 123ms	remaining: 2.5ms
# 98:	learn: 0.1125137	total: 124ms	remaining: 1.25ms
# 99:	learn: 0.1121650	total: 125ms	remaining: 0us
# R2 score: 0.8938475901207797
# MAE: 0.15500461444281194

# %% [markdown]
# ### LightBoost Regression

# %%
import lightgbm as lgb
# Define the ColumnTransformer for one-hot encoding
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse=False, drop='first'), [0, 1, 7, 10, 11])
], remainder='passthrough')

# Define the LightGBM Regressor
step2 = lgb.LGBMRegressor(n_estimators=100, learning_rate=0.1)  # You can adjust the hyperparameters as needed

# Create the pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Fit the pipeline to the training data
pipe.fit(X_train, y_train)

# Make predictions on the test data
y_pred = pipe.predict(X_test)

# Evaluate the model
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000253 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 207
# [LightGBM] [Info] Number of data points in the train set: 1106, number of used features: 26
# [LightGBM] [Info] Start training from score 10.821185
# R2 score: 0.9014933263116596
# MAE: 0.15188868526679372

# %% [markdown]
# ### neural networks

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler, LabelEncoder



# Perform one-hot encoding for categorical features
categorical_cols = ['Company', 'Type Name', 'CPU Brand', 'GPU Brand', 'OS']
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Normalize/Scale the input features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Reshape the data for a "fake" image-like structure
num_features = X_encoded.shape[1]
X_train_cnn = X_train.reshape(-1, num_features, 1)
X_test_cnn = X_test.reshape(-1, num_features, 1)

# Build a simple CNN model
model = keras.Sequential([
    keras.layers.Conv1D(32, 3, activation='relu', input_shape=(num_features, 1)),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(1)  # Output layer with 1 neuron for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
history = model.fit(X_train_cnn, y_train, epochs=100, batch_size=32, validation_data=(X_test_cnn, y_test))

# Evaluate the model on the test data
loss, mae = model.evaluate(X_test_cnn, y_test)
print(f"Mean Absolute Error on Test Data: {mae}")
y_pred = model.predict(X_test_cnn)

# Calculate R2 score
r2 = r2_score(y_test, y_pred)
print(f"R2 Score on Test Data: {r2}")
# Out:
# Epoch 1/100
# 33/33 [==============================] - 1s 8ms/step - loss: 31.9515 - mae: 4.4444 - val_loss: 5.4241 - val_mae: 1.4077
# Epoch 2/100
# 33/33 [==============================] - 0s 5ms/step - loss: 2.2523 - mae: 1.0823 - val_loss: 1.4421 - val_mae: 0.7687
# Epoch 3/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.7423 - mae: 0.6313 - val_loss: 0.5821 - val_mae: 0.5539
# Epoch 4/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.3618 - mae: 0.4713 - val_loss: 0.3289 - val_mae: 0.4375
# Epoch 5/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2586 - mae: 0.3991 - val_loss: 0.2434 - val_mae: 0.3808
# Epoch 6/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.2118 - mae: 0.3596 - val_loss: 0.2063 - val_mae: 0.3487
# Epoch 7/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1831 - mae: 0.3350 - val_loss: 0.1794 - val_mae: 0.3277
# Epoch 8/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1640 - mae: 0.3148 - val_loss: 0.1678 - val_mae: 0.3184
# Epoch 9/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1481 - mae: 0.2998 - val_loss: 0.1435 - val_mae: 0.2945
# Epoch 10/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1343 - mae: 0.2850 - val_loss: 0.1319 - val_mae: 0.2836
# Epoch 11/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1244 - mae: 0.2763 - val_loss: 0.1258 - val_mae: 0.2754
# Epoch 12/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1137 - mae: 0.2619 - val_loss: 0.1207 - val_mae: 0.2712
# Epoch 13/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1062 - mae: 0.2543 - val_loss: 0.1064 - val_mae: 0.2560
# Epoch 14/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0995 - mae: 0.2438 - val_loss: 0.1002 - val_mae: 0.2487
# Epoch 15/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0951 - mae: 0.2398 - val_loss: 0.0969 - val_mae: 0.2471
# Epoch 16/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0891 - mae: 0.2319 - val_loss: 0.0974 - val_mae: 0.2446
# Epoch 17/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0880 - mae: 0.2289 - val_loss: 0.0864 - val_mae: 0.2337
# Epoch 18/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0819 - mae: 0.2211 - val_loss: 0.0963 - val_mae: 0.2444
# Epoch 19/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0806 - mae: 0.2205 - val_loss: 0.0870 - val_mae: 0.2327
# Epoch 20/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0799 - mae: 0.2190 - val_loss: 0.0839 - val_mae: 0.2288
# Epoch 21/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0778 - mae: 0.2162 - val_loss: 0.0895 - val_mae: 0.2375
# Epoch 22/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0734 - mae: 0.2107 - val_loss: 0.0773 - val_mae: 0.2213
# Epoch 23/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0717 - mae: 0.2069 - val_loss: 0.0730 - val_mae: 0.2187
# Epoch 24/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0693 - mae: 0.2027 - val_loss: 0.0735 - val_mae: 0.2160
# Epoch 25/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0677 - mae: 0.2014 - val_loss: 0.0711 - val_mae: 0.2150
# Epoch 26/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0667 - mae: 0.1998 - val_loss: 0.0708 - val_mae: 0.2142
# Epoch 27/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0654 - mae: 0.1971 - val_loss: 0.0695 - val_mae: 0.2134
# Epoch 28/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0642 - mae: 0.1967 - val_loss: 0.0673 - val_mae: 0.2099
# Epoch 29/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0630 - mae: 0.1945 - val_loss: 0.0692 - val_mae: 0.2138
# Epoch 30/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0638 - mae: 0.1964 - val_loss: 0.0650 - val_mae: 0.2054
# Epoch 31/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0610 - mae: 0.1928 - val_loss: 0.0723 - val_mae: 0.2177
# Epoch 32/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0620 - mae: 0.1933 - val_loss: 0.0647 - val_mae: 0.2036
# Epoch 33/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0597 - mae: 0.1890 - val_loss: 0.0642 - val_mae: 0.2045
# Epoch 34/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0609 - mae: 0.1917 - val_loss: 0.0728 - val_mae: 0.2162
# Epoch 35/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0601 - mae: 0.1918 - val_loss: 0.0669 - val_mae: 0.2047
# Epoch 36/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0625 - mae: 0.1939 - val_loss: 0.0755 - val_mae: 0.2130
# Epoch 37/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0601 - mae: 0.1883 - val_loss: 0.0663 - val_mae: 0.2066
# Epoch 38/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0626 - mae: 0.1862 - val_loss: 0.0693 - val_mae: 0.2059
# Epoch 39/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0706 - mae: 0.1883 - val_loss: 0.0625 - val_mae: 0.1996
# Epoch 40/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0847 - mae: 0.1918 - val_loss: 0.0674 - val_mae: 0.2059
# Epoch 41/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0580 - mae: 0.1860 - val_loss: 0.0935 - val_mae: 0.2110
# Epoch 42/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0681 - mae: 0.1937 - val_loss: 0.0888 - val_mae: 0.2342
# Epoch 43/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0655 - mae: 0.1869 - val_loss: 0.0761 - val_mae: 0.2174
# Epoch 44/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0638 - mae: 0.1880 - val_loss: 0.0744 - val_mae: 0.2051
# Epoch 45/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0582 - mae: 0.1833 - val_loss: 0.0609 - val_mae: 0.1950
# Epoch 46/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0584 - mae: 0.1852 - val_loss: 0.0664 - val_mae: 0.2033
# Epoch 47/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0578 - mae: 0.1838 - val_loss: 0.0709 - val_mae: 0.2138
# Epoch 48/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0587 - mae: 0.1879 - val_loss: 0.0640 - val_mae: 0.1988
# Epoch 49/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0570 - mae: 0.1838 - val_loss: 0.0608 - val_mae: 0.1939
# Epoch 50/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0579 - mae: 0.1845 - val_loss: 0.0649 - val_mae: 0.2029
# Epoch 51/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0565 - mae: 0.1819 - val_loss: 0.0641 - val_mae: 0.2006
# Epoch 52/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0566 - mae: 0.1842 - val_loss: 0.0700 - val_mae: 0.2117
# Epoch 53/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0571 - mae: 0.1833 - val_loss: 0.0624 - val_mae: 0.1975
# Epoch 54/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0560 - mae: 0.1793 - val_loss: 0.0642 - val_mae: 0.1978
# Epoch 55/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0580 - mae: 0.1796 - val_loss: 0.0686 - val_mae: 0.2077
# Epoch 56/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0569 - mae: 0.1808 - val_loss: 0.0646 - val_mae: 0.1990
# Epoch 57/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0566 - mae: 0.1829 - val_loss: 0.0680 - val_mae: 0.2026
# Epoch 58/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0557 - mae: 0.1772 - val_loss: 0.0735 - val_mae: 0.2043
# Epoch 59/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0533 - mae: 0.1763 - val_loss: 0.0766 - val_mae: 0.1975
# Epoch 60/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0616 - mae: 0.1847 - val_loss: 0.0872 - val_mae: 0.2104
# Epoch 61/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0809 - mae: 0.2021 - val_loss: 0.1436 - val_mae: 0.2313
# Epoch 62/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0886 - mae: 0.2049 - val_loss: 0.1021 - val_mae: 0.2213
# Epoch 63/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0678 - mae: 0.1945 - val_loss: 0.0652 - val_mae: 0.1998
# Epoch 64/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0620 - mae: 0.1844 - val_loss: 0.0773 - val_mae: 0.2043
# Epoch 65/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0634 - mae: 0.1869 - val_loss: 0.0840 - val_mae: 0.2025
# Epoch 66/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0626 - mae: 0.1814 - val_loss: 0.0832 - val_mae: 0.2113
# Epoch 67/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0676 - mae: 0.1873 - val_loss: 0.0832 - val_mae: 0.1992
# Epoch 68/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0590 - mae: 0.1804 - val_loss: 0.0837 - val_mae: 0.2101
# Epoch 69/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0566 - mae: 0.1806 - val_loss: 0.0795 - val_mae: 0.2153
# Epoch 70/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0577 - mae: 0.1788 - val_loss: 0.0726 - val_mae: 0.2042
# Epoch 71/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0617 - mae: 0.1812 - val_loss: 0.0604 - val_mae: 0.1962
# Epoch 72/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0532 - mae: 0.1760 - val_loss: 0.0728 - val_mae: 0.2101
# Epoch 73/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0589 - mae: 0.1902 - val_loss: 0.0738 - val_mae: 0.2076
# Epoch 74/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0586 - mae: 0.1878 - val_loss: 0.0715 - val_mae: 0.2007
# Epoch 75/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0569 - mae: 0.1809 - val_loss: 0.0690 - val_mae: 0.2086
# Epoch 76/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0542 - mae: 0.1796 - val_loss: 0.0722 - val_mae: 0.2046
# Epoch 77/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0606 - mae: 0.1880 - val_loss: 0.0751 - val_mae: 0.2071
# Epoch 78/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0651 - mae: 0.1897 - val_loss: 0.0859 - val_mae: 0.2046
# Epoch 79/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0604 - mae: 0.1795 - val_loss: 0.0877 - val_mae: 0.2141
# Epoch 80/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0660 - mae: 0.1878 - val_loss: 0.1007 - val_mae: 0.2175
# Epoch 81/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0677 - mae: 0.1883 - val_loss: 0.1041 - val_mae: 0.2147
# Epoch 82/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0630 - mae: 0.1831 - val_loss: 0.0770 - val_mae: 0.2159
# Epoch 83/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0527 - mae: 0.1782 - val_loss: 0.0743 - val_mae: 0.2094
# Epoch 84/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0559 - mae: 0.1829 - val_loss: 0.0686 - val_mae: 0.2043
# Epoch 85/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0545 - mae: 0.1786 - val_loss: 0.0686 - val_mae: 0.2003
# Epoch 86/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0553 - mae: 0.1819 - val_loss: 0.0648 - val_mae: 0.2056
# Epoch 87/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0547 - mae: 0.1811 - val_loss: 0.0661 - val_mae: 0.1993
# Epoch 88/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0671 - mae: 0.2014 - val_loss: 0.0652 - val_mae: 0.1957
# Epoch 89/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0542 - mae: 0.1774 - val_loss: 0.0592 - val_mae: 0.1875
# Epoch 90/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0522 - mae: 0.1775 - val_loss: 0.0694 - val_mae: 0.2081
# Epoch 91/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0563 - mae: 0.1846 - val_loss: 0.0721 - val_mae: 0.2019
# Epoch 92/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0610 - mae: 0.1849 - val_loss: 0.0978 - val_mae: 0.2190
# Epoch 93/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0659 - mae: 0.1862 - val_loss: 0.1223 - val_mae: 0.2084
# Epoch 94/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0918 - mae: 0.1971 - val_loss: 0.2122 - val_mae: 0.2232
# Epoch 95/100
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1208 - mae: 0.2013 - val_loss: 0.0896 - val_mae: 0.2322
# Epoch 96/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0804 - mae: 0.2030 - val_loss: 0.0672 - val_mae: 0.2089
# Epoch 97/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0592 - mae: 0.1792 - val_loss: 0.0789 - val_mae: 0.2193
# Epoch 98/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0568 - mae: 0.1853 - val_loss: 0.0701 - val_mae: 0.2080
# Epoch 99/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0540 - mae: 0.1767 - val_loss: 0.0736 - val_mae: 0.2084
# Epoch 100/100
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0608 - mae: 0.1883 - val_loss: 0.0809 - val_mae: 0.2049
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0809 - mae: 0.2049
# Mean Absolute Error on Test Data: 0.20487052202224731
# 9/9 [==============================] - 0s 2ms/step
# R2 Score on Test Data: 0.7899624739146456

# %% [markdown]
# ### neural networks sequential regression

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.preprocessing import StandardScaler, LabelEncoder



# Perform one-hot encoding for categorical features
categorical_cols = ['Company', 'Type Name', 'CPU Brand', 'GPU Brand', 'OS']
X_encoded = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Normalize/Scale the input features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build the neural network model
model = keras.Sequential([
    keras.layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
       
    keras.layers.Dense(64, activation='elu'),
    
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1)  # Output layer with 1 neuron for regression
])

optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error')

# Train the model with a larger number of epochs and early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,  # Adjust patience as needed
    restore_best_weights=True
)

history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping])

# Make predictions on the test data
y_pred = model.predict(X_test)

# Calculate the R2 score
r2 = r2_score(y_test, y_pred)
print(f"R2 Score: {r2}")
# Out:
# Epoch 1/200
# 33/33 [==============================] - 1s 5ms/step - loss: 30.4679 - val_loss: 5.5115
# Epoch 2/200
# 33/33 [==============================] - 0s 3ms/step - loss: 2.2802 - val_loss: 1.0376
# Epoch 3/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5962 - val_loss: 0.7654
# Epoch 4/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3619 - val_loss: 0.3170
# Epoch 5/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2838 - val_loss: 0.7265
# Epoch 6/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2353 - val_loss: 0.1499
# Epoch 7/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2075 - val_loss: 0.4869
# Epoch 8/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1900 - val_loss: 0.1927
# Epoch 9/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1826 - val_loss: 0.3220
# Epoch 10/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1545 - val_loss: 0.1894
# Epoch 11/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1657 - val_loss: 0.1237
# Epoch 12/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1486 - val_loss: 0.1461
# Epoch 13/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1615 - val_loss: 0.1152
# Epoch 14/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1364 - val_loss: 0.1149
# Epoch 15/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1190 - val_loss: 0.1276
# Epoch 16/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1238 - val_loss: 0.1069
# Epoch 17/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1411 - val_loss: 0.1191
# Epoch 18/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1115 - val_loss: 0.2204
# Epoch 19/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1229 - val_loss: 0.1900
# Epoch 20/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1109 - val_loss: 0.1199
# Epoch 21/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1155 - val_loss: 0.0960
# Epoch 22/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1009 - val_loss: 0.1815
# Epoch 23/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0941 - val_loss: 0.1663
# Epoch 24/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1037 - val_loss: 0.1831
# Epoch 25/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0989 - val_loss: 0.0878
# Epoch 26/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1000 - val_loss: 0.1110
# Epoch 27/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0938 - val_loss: 0.1987
# Epoch 28/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0887 - val_loss: 0.2969
# Epoch 29/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0949 - val_loss: 0.0825
# Epoch 30/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0870 - val_loss: 0.0812
# Epoch 31/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0897 - val_loss: 0.1191
# Epoch 32/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0767 - val_loss: 0.1779
# Epoch 33/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0822 - val_loss: 0.2212
# Epoch 34/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0780 - val_loss: 0.1587
# Epoch 35/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0807 - val_loss: 0.0797
# Epoch 36/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0787 - val_loss: 0.1387
# Epoch 37/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0758 - val_loss: 0.1502
# Epoch 38/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0888 - val_loss: 0.0872
# Epoch 39/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0718 - val_loss: 0.0783
# Epoch 40/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0696 - val_loss: 0.2686
# Epoch 41/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0833 - val_loss: 0.0793
# Epoch 42/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0660 - val_loss: 0.1222
# Epoch 43/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0580 - val_loss: 0.1681
# Epoch 44/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0808 - val_loss: 0.0616
# Epoch 45/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0737 - val_loss: 0.0797
# Epoch 46/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0708 - val_loss: 0.0936
# Epoch 47/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0598 - val_loss: 0.0597
# Epoch 48/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0687 - val_loss: 0.1344
# Epoch 49/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0613 - val_loss: 0.2606
# Epoch 50/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0693 - val_loss: 0.1089
# Epoch 51/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0584 - val_loss: 0.0613
# Epoch 52/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0609 - val_loss: 0.1330
# Epoch 53/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0671 - val_loss: 0.0758
# Epoch 54/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0610 - val_loss: 0.0580
# Epoch 55/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0699 - val_loss: 0.0711
# Epoch 56/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0593 - val_loss: 0.0986
# Epoch 57/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0560 - val_loss: 0.0656
# Epoch 58/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0558 - val_loss: 0.0733
# Epoch 59/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0606 - val_loss: 0.1053
# Epoch 60/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0546 - val_loss: 0.0680
# Epoch 61/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0607 - val_loss: 0.1464
# Epoch 62/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0595 - val_loss: 0.0651
# Epoch 63/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0574 - val_loss: 0.0819
# Epoch 64/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0501 - val_loss: 0.1110
# 9/9 [==============================] - 0s 1ms/step
# R2 Score: 0.8495098797339972
